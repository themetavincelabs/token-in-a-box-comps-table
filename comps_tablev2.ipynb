# %%
###IMPORT LIBRARIES###
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import json #needed?
import requests #needed?

# %%
response = requests.get("https://api.coingecko.com/api/v3/ping")
print(response.status_code)
# Out:
# 200

# %%
#coinlist
#https://api.coingecko.com/api/v3/coins/list

# %%
pip install -U pycoingecko
# Out:
# Requirement already satisfied: pycoingecko in c:\users\vincentramsey\anaconda3\lib\site-packages (3.1.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: requests in c:\users\vincentramsey\anaconda3\lib\site-packages (from pycoingecko) (2.28.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\vincentramsey\anaconda3\lib\site-packages (from requests->pycoingecko) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vincentramsey\anaconda3\lib\site-packages (from requests->pycoingecko) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vincentramsey\anaconda3\lib\site-packages (from requests->pycoingecko) (2022.9.14)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\vincentramsey\anaconda3\lib\site-packages (from requests->pycoingecko) (1.26.11)

# %%
from pycoingecko import CoinGeckoAPI
cg = CoinGeckoAPI()

# %%
cg.get_price(ids='apecoin', vs_currencies='usd')
# Out:
# {'apecoin': {'usd': 5.88}}

# %%
#pulls from /coins/markets (List all supported coins price, market cap, volume, and market related data)
#reference json https://api.coingecko.com/api/v3/coins/markets?vs_currency=usd&ids=apecoin&order=market_cap_desc&per_page=100&page=1&sparkline=false
coinMarketData = cg.get_coins_markets(ids='apecoin,the-sandbox,decentraland,metahero,crypto-raiders,wolf-game-wool,zed-run,decentral-games,ethereum-name-service',
    vs_currency='usd')
price_df = pd.DataFrame(coinMarketData)
price_df.head(10)
# Out:
#                       id  symbol                   name  \
# 0                apecoin     ape                ApeCoin
# 1           decentraland    mana           Decentraland
# 2            the-sandbox    sand            The Sandbox
# 3  ethereum-name-service     ens  Ethereum Name Service
# 4               metahero    hero               Metahero
# 5        decentral-games      dg        Decentral Games
# 6         crypto-raiders  raider         Crypto Raiders
# 7         wolf-game-wool    wool         Wolf Game Wool
# 8                zed-run     zed                ZED RUN
#
#                                                image  current_price  \
# 0  https://assets.coingecko.com/coins/images/2438...       5.830000
# 1  https://assets.coingecko.com/coins/images/878/...       0.738167
# 2  https://assets.coingecko.com/coins/images/1212...       0.716014
# 3  https://assets.coingecko.com/coins/images/1978...      15.990000
# 4  https://assets.coingecko.com/coins/images/1691...       0.005005
# 5  https://assets.coingecko.com/coins/images/2117...       0.024560
# 6  https://assets.coingecko.com/coins/images/1763...       0.088024
# 7  https://assets.coingecko.com/coins/images/2076...       0.018173
# 8  https://assets.coingecko.com/coins/images/2660...       0.030099
#
#      market_cap  market_cap_rank  fully_diluted_valuation  total_volume  \
# 0  2.148759e+09             31.0               5829613482     143149886
# 1  1.344087e+09             41.0               1619315994     234335761
# 2  1.137271e+09             46.0               2149129443     161485278
# 3  4.121557e+08            103.0               1598541613      54494516
# 4  3.936581e+07            488.0                 50044168        741133
# 5  1.548992e+07            804.0                 24557826        171423
# 6  1.897160e+06           1632.0                  8802149         23063
# 7  0.000000e+00              NaN                 90864313        228916
# 8  0.000000e+00              NaN                 30119256         95703
#
#     high_24h  ...  total_supply    max_supply        ath  \
# 0   5.980000  ...  1.000000e+09  1.000000e+09  26.700000
# 1   0.769764  ...  2.193226e+09  2.193226e+09   5.850000
# 2   0.743092  ...  3.000000e+09  3.000000e+09   8.400000
# 3  16.440000  ...  1.000000e+08  1.000000e+08  83.400000
# 4   0.005084  ...  9.766213e+09  1.000000e+10   0.252021
# 5   0.025620  ...  6.307528e+08  1.000000e+09   1.630000
# 6   0.093860  ...  1.000000e+08  1.000000e+08  13.540000
# 7   0.019179  ...  7.661084e+07  5.000000e+09   0.530859
# 8   0.031605  ...  1.000000e+09  1.000000e+09   0.192312
#
#    ath_change_percentage                  ath_date       atl  \
# 0              -78.09572  2022-04-28T21:44:21.164Z  2.630000
# 1              -87.38081  2021-11-25T10:04:18.534Z  0.009237
# 2              -91.52281  2021-11-25T06:04:40.957Z  0.028978
# 3              -80.75459  2021-11-11T02:20:01.099Z  7.450000
# 4              -98.00723  2021-12-02T00:09:05.991Z  0.002095
# 5              -98.48620  2021-12-02T10:54:22.100Z  0.020101
# 6              -99.35082  2022-01-05T09:07:08.692Z  0.039124
# 7              -96.56756  2022-01-20T04:07:38.856Z  0.013405
# 8              -84.26723  2022-07-30T09:28:56.773Z  0.020154
#
#    atl_change_percentage                  atl_date  \
# 0              122.68276  2022-11-14T04:22:00.792Z
# 1             7893.30236  2017-10-31T00:00:00.000Z
# 2             2356.42014  2020-11-04T15:59:14.441Z
# 3              115.38100  2022-06-14T02:00:36.378Z
# 4              139.70463  2022-09-21T21:55:09.447Z
# 5               22.40461  2023-01-25T15:02:22.957Z
# 6              124.63823  2023-01-01T17:01:32.479Z
# 7               35.92921  2022-06-13T03:44:46.638Z
# 8               50.12392  2022-11-21T12:50:42.930Z
#
#                                                  roi              last_updated
# 0                                               None  2023-02-01T07:41:11.402Z
# 1  {'times': 35.90837403203352, 'currency': 'usd'...  2023-02-01T07:41:12.070Z
# 2                                               None  2023-02-01T07:41:18.180Z
# 3                                               None  2023-02-01T07:41:11.656Z
# 4                                               None  2023-02-01T07:40:50.534Z
# 5                                               None  2023-02-01T07:41:15.303Z
# 6                                               None  2023-02-01T07:41:17.341Z
# 7                                               None  2023-02-01T07:40:54.079Z
# 8                                               None  2023-02-01T07:41:17.795Z
#
# [9 rows x 26 columns]

# %%
#desired columns
price_df[["name","fully_diluted_valuation","total_volume"]]
# Out:
#                     name  fully_diluted_valuation  total_volume
# 0                ApeCoin               5829613482     143149886
# 1           Decentraland               1619315994     234335761
# 2            The Sandbox               2149129443     161485278
# 3  Ethereum Name Service               1598541613      54494516
# 4               Metahero                 50044168        741133
# 5        Decentral Games                 24557826        171423
# 6         Crypto Raiders                  8802149         23063
# 7         Wolf Game Wool                 90864313        228916
# 8                ZED RUN                 30119256         95703

# %%
#https://api.coingecko.com/api/v3/nfts/bored-ape-yacht-club
bayc = cg.get_nfts_by_id(id='bored-ape-yacht-club')
bayc_df = pd.DataFrame(bayc)
bayc_df[["floor_price","market_cap","volume_24h"]]
# Out:
#                  floor_price    market_cap  volume_24h
# small                    NaN           NaN         NaN
# native_currency        64.49  6.447710e+05      295.08
# usd                101998.00  1.019780e+09   466705.00

# %%
bayc_df.loc[bayc_df.index[1],["floor_price","market_cap","volume_24h"]]
# Out:
# floor_price       64.49
# market_cap     644771.0
# volume_24h       295.08
# Name: native_currency, dtype: object

# %%
###additional nft ids###

#mutant-ape-yacht-club
#otherdeed-for-otherside
#bored-ape-kennel-club

#wolf-game-land
#wolf-game

#decentraland

#sandbox

#metahero
#metahero-universe-core-identities
#metahero-universe-united-planets

#zed-run-legacy

#decentral-games-ice

#ens-ethereum-name-service
